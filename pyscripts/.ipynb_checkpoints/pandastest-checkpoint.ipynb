# %%
import pandas as pd
import numpy as np
import sweetviz
import scipy
from scipy import stats
import subprocess
pd.options.display.max_columns = None


from tkinter import Tk

from tkinter.filedialog import askopenfilename

# %%
_filename_dwellings='Data/Жилые_Задача2.csv'
Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
if askopenfilename()!='':
    _filename_dwellings = askopenfilename() # show an "Open" dialog box and return the path to the selected file
print(_filename_dwellings)
# Out:
# Data/Жилые_Задача2.csv

# %%
dwellings=pd.read_csv(_filename_dwellings)
dwellings
# Out:
#       Город         Id города          StableId          X          Y  Индекс  \
# 0    Москва  4504222397630173  4504235282557431  37.544302  55.590103  117463
# 1    Москва  4504222397630173  4504235282557433  37.541573  55.590751  117463
# 2    Москва  4504222397630173  4504235282557434  37.538825  55.591416  117463
# 3    Москва  4504222397630173  4504235282557436  37.535992  55.592098  117463
# 4    Москва  4504222397630173  4504235282557459  37.543789  55.591608  117463
# ..      ...               ...               ...        ...        ...     ...
# 325  Москва  4504222397630173  4504235283050022  37.548619  55.616044  117593
# 326  Москва  4504222397630173  4504235283050024  37.543529  55.618447  117593
# 327  Москва  4504222397630173  4504235283106596  37.485790  55.633614  117133
# 328  Москва  4504222397630173  4504235283114407  37.485010  55.632915  117133
# 329  Москва  4504222397630173  4504235312032054  37.556561  55.606439  117593
#
#     Название                                 Назначение Название слоя  \
# 0        NaN  Жилой дом с административными помещениями    Жилые дома
# 1        NaN  Жилой дом с административными помещениями    Жилые дома
# 2        NaN  Жилой дом с административными помещениями    Жилые дома
# 3        NaN  Жилой дом с административными помещениями    Жилые дома
# 4        NaN                                  Жилой дом    Жилые дома
# ..       ...                                        ...           ...
# 325      NaN  Жилой дом с административными помещениями    Жилые дома
# 326      NaN                                  Жилой дом    Жилые дома
# 327      NaN  Жилой дом с административными помещениями    Жилые дома
# 328      NaN  Жилой дом с административными помещениями    Жилые дома
# 329      NaN                                  Жилой дом    Жилые дома
#
#      Застройщики                   Субъект федерации  Район области  \
# 0            NaN  Москва город федерального значения            NaN
# 1            NaN  Москва город федерального значения            NaN
# 2            NaN  Москва город федерального значения            NaN
# 3            NaN  Москва город федерального значения            NaN
# 4            NaN  Москва город федерального значения            NaN
# ..           ...                                 ...            ...
# 325          NaN  Москва город федерального значения            NaN
# 326          NaN  Москва город федерального значения            NaN
# 327          NaN  Москва город федерального значения            NaN
# 328          NaN  Москва город федерального значения            NaN
# 329          NaN  Москва город федерального значения            NaN
#
#            Район  Площадь  Этажность  Количество подъездов  \
# 0        Ясенево    29771         16                     6
# 1        Ясенево    29771         16                     3
# 2        Ясенево    29771         16                     6
# 3        Ясенево    29766         16                     6
# 4        Ясенево    36852          9                    16
# ..           ...      ...        ...                   ...
# 325      Ясенево    19976         16                     4
# 326      Ясенево    19978         16                     4
# 327  Тёплый Стан    43535         16                     5
# 328  Тёплый Стан    44677         16                     5
# 329      Ясенево    19976         16                     4
#
#      Количество квартир  коэф семейности 2.7  \
# 0                   360                  972
# 1                   360                  972
# 2                   360                  972
# 3                   360                  972
# 4                   567                 1531
# ..                  ...                  ...
# 325                 256                  691
# 326                 256                  691
# 327                 311                  840
# 328                 378                 1021
# 329                 256                  691
#
#                                    Округ                       Улица1   Дом1  \
# 0    Юго-Западный административный округ          Инессы Арманд улица   8/17
# 1    Юго-Западный административный округ             Карамзина проезд  13 к1
# 2    Юго-Западный административный округ             Карамзина проезд   9 к1
# 3    Юго-Западный административный округ             Карамзина проезд      5
# 4    Юго-Западный административный округ          Инессы Арманд улица   4 к1
# ..                                   ...                          ...    ...
# 325  Юго-Западный административный округ            Соловьиный проезд   4 к1
# 326  Юго-Западный административный округ           Айвазовского улица      1
# 327  Юго-Западный административный округ  Академика Виноградова улица      9
# 328  Юго-Западный административный округ  Академика Виноградова улица      5
# 329  Юго-Западный административный округ            Соловьиный проезд  16 к1
#
#                Улица2 Дом2  Улица3  Дом3
# 0    Карамзина проезд   17     NaN   NaN
# 1                 NaN  NaN     NaN   NaN
# 2                 NaN  NaN     NaN   NaN
# 3                 NaN  NaN     NaN   NaN
# 4                 NaN  NaN     NaN   NaN
# ..                ...  ...     ...   ...
# 325               NaN  NaN     NaN   NaN
# 326               NaN  NaN     NaN   NaN
# 327               NaN  NaN     NaN   NaN
# 328               NaN  NaN     NaN   NaN
# 329               NaN  NaN     NaN   NaN
#
# [330 rows x 25 columns]

# %%
_filename_poi='Data/POI_Задача2.csv'
Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
if askopenfilename()!='':
    _filename_poi = askopenfilename() # show an "Open" dialog box and return the path to the selected file
print(_filename_poi)
# Out:
# Data/POI_Задача2.csv

# %%
poi = pd.read_csv(_filename_poi)


poi_sorted=poi.copy().sort_values(by=['Rubric','Organization_name' ]).reset_index()

# %%
poi_sorted
# Out:
#      index            Id_card            Id_firm  \
# 0      106  70000001029366385   4504137598354185
# 1      107  70000001036669765   4504137598354185
# 2      108  70000001027922570   4504137598354185
# 3      197  70000001041204533  70000001041204532
# 4      198  70000001041162411  70000001041162410
# ..     ...                ...                ...
# 314    154  70000001033148207  70000001033148206
# 315     90  70000001041101137   4504136498285097
# 316     66   4504127908738351   4504136498471507
# 317     16  70000001038420800  70000001038409492
# 318     56  70000001024343211  70000001019904611
#
#                                      Organization_name  \
# 0                      Красное & белое, сеть магазинов
# 1                      Красное & белое, сеть магазинов
# 2                      Красное & белое, сеть магазинов
# 3                                              Пекарня
# 4                                              Пекарня
# ..                                                 ...
# 314                       Магазин чая, кофе и шоколада
# 315  Кантата, сеть галерей чая, кофе и эксклюзивных...
# 316                         Детская школа искусств №11
# 317              London Express, лингвистическая школа
# 318  Гарантия Знаний, обучающий центр по робототехн...
#
#                                                 Rubric Project  \
# 0    Алкогольные напитки|Магазины разливного пива|П...  Москва
# 1       Алкогольные напитки|Продовольственные магазины  Москва
# 2       Алкогольные напитки|Продовольственные магазины  Москва
# 3                Быстрое питание|Хлебобулочные изделия  Москва
# 4                Быстрое питание|Хлебобулочные изделия  Москва
# ..                                                 ...     ...
# 314                    Чай / Кофе|Кондитерские изделия  Москва
# 315  Чай / Кофе|Кондитерские изделия|Сувенирные ком...  Москва
# 316                                     Школы искусств  Москва
# 317  Языковые школы|Перевод с иностранных языков|Об...  Москва
# 318  Языковые школы|Центры раннего развития детей|К...  Москва
#
#                                 Subject  district_ofsubject       city  \
# 0    Москва город федерального значения                 NaN  Москва г.
# 1    Москва город федерального значения                 NaN  Москва г.
# 2    Москва город федерального значения                 NaN  Москва г.
# 3    Москва город федерального значения                 NaN  Москва г.
# 4    Москва город федерального значения                 NaN  Москва г.
# ..                                  ...                 ...        ...
# 314  Москва город федерального значения                 NaN  Москва г.
# 315  Москва город федерального значения                 NaN  Москва г.
# 316  Москва город федерального значения                 NaN  Москва г.
# 317  Москва город федерального значения                 NaN  Москва г.
# 318  Москва город федерального значения                 NaN  Москва г.
#
#     index_of_city  post_index                   street   house_num  \
# 0     Тёплый Стан      117465  Генерала Тюленева улица         29а
# 1     Тёплый Стан      117321        Профсоюзная улица  152 к2 ст2
# 2     Тёплый Стан      117465  Генерала Тюленева улица         41а
# 3         Ясенево      117588  Новоясеневский проспект       1Б к1
# 4         Ясенево      117588  Новоясеневский проспект       1Б к6
# ..            ...         ...                      ...         ...
# 314   Тёплый Стан      117133        Тёплый Стан улица          10
# 315       Ясенево      117588  Новоясеневский проспект           7
# 316       Ясенево      117463       Паустовского улица        5 к3
# 317       Ясенево      117593        Соловьиный проезд           1
# 318       Ясенево      117588        Литовский бульвар       42 к1
#
#                houseId                             Callphones  \
# 0     4504235282589232                                    NaN
# 1     4504235282569463                                    NaN
# 2     4504235282603289                                    NaN
# 3     4504235310822427                                    NaN
# 4    70030076162970480                                    NaN
# ..                 ...                                    ...
# 314   4504235282589660                       +7-916-437-46-00
# 315   4504235283044653    +7-968-773-97-48|+7 (499) 709-80-74
# 316   4504235282558091  +7 (495) 423-05-61|+7 (495) 426-16-27
# 317   4504235282559923                     +7 (499) 390-78-78
# 318   4504235282561035    +7 (495) 127-78-33|+7-917-568-07-11
#
#                           Email                     Sites  \
# 0                           NaN      www.krasnoeibeloe.ru
# 1                           NaN      www.krasnoeibeloe.ru
# 2                           NaN      www.krasnoeibeloe.ru
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ..                          ...                       ...
# 314         ochaykofe@yandex.ru                       NaN
# 315          hotline@cantata.ru            www.cantata.ru
# 316            dshi11@yandex.ru            11.arts.mos.ru
# 317    moscow@london-express.ru  moskva.london-express.ru
# 318  info77@garantylearning.com       garantylearning.com
#
#                                         SocialNetworks  \
# 0    krasnoebeloe|krasnoebeloe|krasnoebeloe|krasnoe...
# 1    krasnoebeloe|krasnoebeloe|krasnoebeloe|krasnoe...
# 2    krasnoebeloe|krasnoebeloe|krasnoebeloe|krasnoe...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 314                                                NaN
# 315                         ccantata|ccantata|ccantata
# 316                                                NaN
# 317  londonexpress_moscow|moskva.london-express.ru|...
# 318  znaniya_courses|garanty_to_know|garantylearnin...
#
#                             how_to_pay  \
# 0     Наличный расчёт|Расчёт по картам
# 1     Наличный расчёт|Расчёт по картам
# 2     Наличный расчёт|Расчёт по картам
# 3                      Наличный расчёт
# 4                      Наличный расчёт
# ..                                 ...
# 314                    Наличный расчёт
# 315   Наличный расчёт|Расчёт по картам
# 316                  Оплата через банк
# 317   Наличный расчёт|Расчёт по картам
# 318  Наличный расчёт|Оплата через банк
#
#                                          work_schedule  philial_amount  \
# 0    Понедельник: с 9:00 до 22:05|Вторник: с 9:00 д...             835
# 1    Понедельник: с 9:00 до 22:05|Вторник: с 9:00 д...             835
# 2    Понедельник: с 9:00 до 22:05|Вторник: с 9:00 д...             835
# 3    Понедельник: с 8:00 до 20:00|Вторник: с 8:00 д...               1
# 4    Понедельник: с 8:00 до 18:00|Вторник: с 8:00 д...               1
# ..                                                 ...             ...
# 314  Понедельник: с 10:00 до 20:00|Вторник: с 10:00...               1
# 315  Понедельник: с 10:00 до 22:00|Вторник: с 10:00...             133
# 316  Понедельник: с 9:00 до 20:00|Вторник: с 9:00 д...               1
# 317  Понедельник: с 10:00 до 22:00|Вторник: с 10:00...               2
# 318  Понедельник: с 8:00 до 20:00|Вторник: с 8:00 д...               9
#
#            lat        lon
# 0    55.617273  37.489496
# 1    55.622874  37.506404
# 2    55.613858  37.494008
# 3    55.617806  37.511738
# 4    55.619235  37.511776
# ..         ...        ...
# 314  55.629040  37.486104
# 315  55.607389  37.532023
# 316  55.599269  37.544233
# 317  55.619538  37.544286
# 318  55.607754  37.544239
#
# [319 rows x 23 columns]

# %%
_filename_rubrics='Data/Рубрики_Россия_01.20.csv'
Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
if askopenfilename()!='':
    _filename_rubrics = askopenfilename() # show an "Open" dialog box and return the path to the selected file
print(_filename_rubrics)
# Out:
# Data/Рубрики_Россия_01.20.csv

# %%
rubrics=pd.read_csv(_filename_rubrics)
rubrics
# Out:
#    Код рубрики                                   Категория  \
# 0          537  Досуг / Развлечения / Общественное питание
# 1        11648  Досуг / Развлечения / Общественное питание
# 2       110358  Досуг / Развлечения / Общественное питание
# 3       100772  Досуг / Развлечения / Общественное питание
# 4        24169  Досуг / Развлечения / Общественное питание
# ..         ...                                         ...
# 81         234              Образование / Работа / Карьера
# 82       50532              Образование / Работа / Карьера
# 83         518              Образование / Работа / Карьера
# 84       19499           Торговые комплексы / Спецмагазины
# 85         611           Торговые комплексы / Спецмагазины
#
#                                 Рубрика 2го уровня  \
# 0         Места отдыха / Развлекательные заведения
# 1         Места отдыха / Развлекательные заведения
# 2         Места отдыха / Развлекательные заведения
# 3         Места отдыха / Развлекательные заведения
# 4         Места отдыха / Развлекательные заведения
# ..                                             ...
# 81  Дополнительное образование / Развивающие курсы
# 82  Дополнительное образование / Развивающие курсы
# 83  Дополнительное образование / Развивающие курсы
# 84                              Торговые комплексы
# 85                              Торговые комплексы
#
#                                               Рубрика
# 0                      Аквапарки / Водные аттракционы
# 1                                       Акватеррариум
# 2                                         Аттракционы
# 3                          Аэродинамические комплексы
# 4                        Ботанический сад / Дендрарий
# ..                                                ...
# 81  Профессиональная переподготовка / Повышение кв...
# 82                                  Театральные курсы
# 83                                     Школы искусств
# 84             Торгово-развлекательные центры / Моллы
# 85           Торговые центры / Универсальные магазины
#
# [86 rows x 4 columns]

# %%
column_names = ["Dataset"]
newDatasets=pd.DataFrame(columns=column_names)
for i in range(len(poi_sorted)):
    for j in range(len(rubrics)-1):
        newDataset=pd.DataFrame(columns=poi_sorted.columns)
        for k in range(len(poi_sorted['Rubric'][i].split('|'))):
            if poi_sorted['Rubric'][i].split('|')[k] in rubrics.Рубрика[j]:
                
    newDatasets.add(newDataset)
                                      
                                     
#my_report = sweetviz.compare([citizens, "Train"], [poi, "Test"], "Survived")
#my_report.show_html("Report.html")

# %%
newDatasets
# Out:
# Empty DataFrame
# Columns: [Dataset]
# Index: []

# %%
 
 
    def make_agg_count(df_in, group_col_name, stat_col_name):
        res = df_in.copy()
        res['X']=df['X']
        res['Y']=df['Y']
        
        # то же самое что и count, количество
        res['col_count'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: s.values.shape[0])
        return res
    
    def make_agg_mean(df_in, group_col_name, stat_col_name):
        res = df_in.copy()
        res['X']=df['X']
        res['Y']=df['Y']
        # среднее значение по сгруппированному столбцу
        res['col_mean'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: np.mean(s.values))
        return res
    def make_agg_median(df_in, group_col_name, stat_col_name):
        res = df_in.copy()
        res['X']=df['X']
        res['Y']=df['Y']
       # медиана по сгруппированному столбцу
        res['col_median'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: np.median(s.values))
        return res
    def make_agg_sum(df_in, group_col_name, stat_col_name):
        res = df_in.copy()
        res['X']=df['X']
        res['Y']=df['Y']
       # сумма по сгруппированному столбцу
        res['col_sum'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: np.sum(s.values))
        return res
    def make_agg_max(df_in, group_col_name, stat_col_name):
        res = df_in.copy()
        res['X']=df['X']
        res['Y']=df['Y']
      # максимум по сгруппированному столбцу
        res['col_max'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: np.max(s.values))
        return res
    def make_agg_min(df_in, group_col_name, stat_col_name):
        res = df_in.copy()
        res['X']=df['X']
        res['Y']=df['Y']
        # минимум по сгруппированному столбцу
        res['col_min'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: np.min(s.values))
        return res
    
    def make_k_familiness(df_in,flats_col_name,family_col_name):
        res=df_in.copy()
        res['amountofpeople']=res[flats_col_name]*res[family_col_name]
        return res
        # стандартное отклонение по сгруппированному столбцу
        #df['col_std'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: np.std(s.values))
        # квантили в 20 и 80 % по сгруппированному столбцу
        # df['col_q20'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: np.quantile(s.values, q=0.2))
        #df['col_q80'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: np.quantile(s.values, q=0.8))
        # skew
        #df['col_skew'] = df.groupby(by=[group_col_name], as_index=False)[stat_col_name].transform(lambda s: scipy.stats.skew(s))
 
       
 
result = make_k_familiness(dwellings,'Количество квартир', 'коэф семейности 2.7')
result

#resultsum=make_agg_sum(result,'amountofpeople',)
# Out:
#       Город         Id города          StableId          X          Y  Индекс  \
# 0    Москва  4504222397630173  4504235282557431  37.544302  55.590103  117463
# 1    Москва  4504222397630173  4504235282557433  37.541573  55.590751  117463
# 2    Москва  4504222397630173  4504235282557434  37.538825  55.591416  117463
# 3    Москва  4504222397630173  4504235282557436  37.535992  55.592098  117463
# 4    Москва  4504222397630173  4504235282557459  37.543789  55.591608  117463
# ..      ...               ...               ...        ...        ...     ...
# 325  Москва  4504222397630173  4504235283050022  37.548619  55.616044  117593
# 326  Москва  4504222397630173  4504235283050024  37.543529  55.618447  117593
# 327  Москва  4504222397630173  4504235283106596  37.485790  55.633614  117133
# 328  Москва  4504222397630173  4504235283114407  37.485010  55.632915  117133
# 329  Москва  4504222397630173  4504235312032054  37.556561  55.606439  117593
#
#     Название                                 Назначение Название слоя  \
# 0        NaN  Жилой дом с административными помещениями    Жилые дома
# 1        NaN  Жилой дом с административными помещениями    Жилые дома
# 2        NaN  Жилой дом с административными помещениями    Жилые дома
# 3        NaN  Жилой дом с административными помещениями    Жилые дома
# 4        NaN                                  Жилой дом    Жилые дома
# ..       ...                                        ...           ...
# 325      NaN  Жилой дом с административными помещениями    Жилые дома
# 326      NaN                                  Жилой дом    Жилые дома
# 327      NaN  Жилой дом с административными помещениями    Жилые дома
# 328      NaN  Жилой дом с административными помещениями    Жилые дома
# 329      NaN                                  Жилой дом    Жилые дома
#
#      Застройщики                   Субъект федерации  Район области  \
# 0            NaN  Москва город федерального значения            NaN
# 1            NaN  Москва город федерального значения            NaN
# 2            NaN  Москва город федерального значения            NaN
# 3            NaN  Москва город федерального значения            NaN
# 4            NaN  Москва город федерального значения            NaN
# ..           ...                                 ...            ...
# 325          NaN  Москва город федерального значения            NaN
# 326          NaN  Москва город федерального значения            NaN
# 327          NaN  Москва город федерального значения            NaN
# 328          NaN  Москва город федерального значения            NaN
# 329          NaN  Москва город федерального значения            NaN
#
#            Район  Площадь  Этажность  Количество подъездов  \
# 0        Ясенево    29771         16                     6
# 1        Ясенево    29771         16                     3
# 2        Ясенево    29771         16                     6
# 3        Ясенево    29766         16                     6
# 4        Ясенево    36852          9                    16
# ..           ...      ...        ...                   ...
# 325      Ясенево    19976         16                     4
# 326      Ясенево    19978         16                     4
# 327  Тёплый Стан    43535         16                     5
# 328  Тёплый Стан    44677         16                     5
# 329      Ясенево    19976         16                     4
#
#      Количество квартир  коэф семейности 2.7  \
# 0                   360                  972
# 1                   360                  972
# 2                   360                  972
# 3                   360                  972
# 4                   567                 1531
# ..                  ...                  ...
# 325                 256                  691
# 326                 256                  691
# 327                 311                  840
# 328                 378                 1021
# 329                 256                  691
#
#                                    Округ                       Улица1   Дом1  \
# 0    Юго-Западный административный округ          Инессы Арманд улица   8/17
# 1    Юго-Западный административный округ             Карамзина проезд  13 к1
# 2    Юго-Западный административный округ             Карамзина проезд   9 к1
# 3    Юго-Западный административный округ             Карамзина проезд      5
# 4    Юго-Западный административный округ          Инессы Арманд улица   4 к1
# ..                                   ...                          ...    ...
# 325  Юго-Западный административный округ            Соловьиный проезд   4 к1
# 326  Юго-Западный административный округ           Айвазовского улица      1
# 327  Юго-Западный административный округ  Академика Виноградова улица      9
# 328  Юго-Западный административный округ  Академика Виноградова улица      5
# 329  Юго-Западный административный округ            Соловьиный проезд  16 к1
#
#                Улица2 Дом2  Улица3  Дом3  amountofpeople
# 0    Карамзина проезд   17     NaN   NaN          349920
# 1                 NaN  NaN     NaN   NaN          349920
# 2                 NaN  NaN     NaN   NaN          349920
# 3                 NaN  NaN     NaN   NaN          349920
# 4                 NaN  NaN     NaN   NaN          868077
# ..                ...  ...     ...   ...             ...
# 325               NaN  NaN     NaN   NaN          176896
# 326               NaN  NaN     NaN   NaN          176896
# 327               NaN  NaN     NaN   NaN          261240
# 328               NaN  NaN     NaN   NaN          385938
# 329               NaN  NaN     NaN   NaN          176896
#
# [330 rows x 26 columns]

# %%
#result.to_csv('../assets/new/test.csv')

newresult=pd.DataFrame()
newresult['x']=result['X']
newresult['y']=result['Y']
newresult['value']=result['amountofpeople']
#newresult.to_json('../map/data/citizensdone.json')
#host = "5432"
#username = "postgres"
#dbname = "web-map"

#table_name = "vitizenstest"
#file_name = result.to_csv('../map/data/test.csv')

#result

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn import datasets
import matplotlib.pyplot as plt
params = {'axes.titlesize':'32',
          'xtick.labelsize':'24',
          'ytick.labelsize':'24'}

matplotlib.rcParams.update(params)

plt.suptitle('Количество людей(в доме)',x=0.5, y=1.05, ha='center',fontsize='xx-large')
#dwellings info
h = result['коэф семейности 2.7'].hist()
fig = h.get_figure()
fig.savefig('../assets/histograms/dwellings/family_ratio_histogram.png')

# %%
plt.suptitle('Количество людей(в доме)',x=0.5, y=1.05, ha='center',fontsize='xx-large')
h = result['amountofpeople'].hist()
fig = h.get_figure()
fig.savefig('../assets/histograms/dwellings/amountofpeople_histogram.png')

# %%
plt.suptitle('Количество подъездов',x=0.5, y=1.05, ha='center',fontsize='xx-large')
h = result['Количество подъездов'].hist()
fig = h.get_figure()
h.figure.savefig('../assets/histograms/dwellings/amountofentrances_histogram.pdf')
fig.savefig('../assets/histograms/dwellings/amountofentrances_histogram.png')

# %%
plt.suptitle('Количество квартир',x=0.5, y=1.05, ha='center',fontsize='xx-large')
result['Количество квартир'].hist()
fig.savefig('../assets/histograms/dwellings/amountoffloors_histogram.png')

# %%
plt.suptitle('Распределение квартир по районам',x=0.5, y=1.05, ha='center',fontsize='xx-large')
result['Район'].hist()
fig.savefig('../assets/histograms/dwellings/district_histogram.png')

# %%
plt.suptitle('Этажность',x=0.5, y=1.05, ha='center',fontsize='xx-large')
result['Этажность'].hist()
fig.savefig('../assets/histograms/dwellings/amountoffloors_histogram.png')

# %%
plt.suptitle('Площадь квартир',x=0.5, y=1.05, ha='center',fontsize='xx-large')
result['Площадь'].hist()
fig.savefig('../assets/histograms/dwellings/s_histogram.png')

# %%
ax = fig.gca()
plt.xticks(rotation=270)
poi_sorted['Rubric'].hist(ax = ax)
fig.savefig('../assets/histograms/rubricshistogram.png')

# %%
poi_sorted['index_of_city'].hist()
fig.savefig('../assets/histograms/poi/districtshistogram.png')

# %%
poi_sorted['philial_amount'].hist()
fig.savefig('../assets/histograms/poi/philial_amounthistogram.png')
